# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# from scipy.misc import imresize
import cv2

# %%
# coding: utf-8

# # Gait Energy Image

# In[1]:


import os
import numpy as np
import matplotlib.pyplot as plt
from imageio import imread
# from scipy.misc import imresize
import cv2
from skimage.transform import resize


# In[2]:


files = os.listdir(r'C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\005\bg-01\144')
images = [imread(r'C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\005\bg-01\144'+'\\'+f) for f in files]


# In[3]:


plt.imshow(images[0])


# In[4]:


def mass_center(img,is_round=True):
    Y = img.mean(axis=1)
    X = img.mean(axis=0)
    Y_ = np.sum(np.arange(Y.shape[0]) * Y)/np.sum(Y)
    X_ = np.sum(np.arange(X.shape[0]) * X)/np.sum(X)
    if is_round:
        return int(round(X_)),int(round(Y_))
    return X_,Y_

def image_extract(img,newsize):
    x_s = np.where(img.mean(axis=0)!=0)[0].min()
    x_e = np.where(img.mean(axis=0)!=0)[0].max()
    
    y_s = np.where(img.mean(axis=1)!=0)[0].min()
    y_e = np.where(img.mean(axis=1)!=0)[0].max()
    
    x_c,_ = mass_center(img)
#     x_c = (x_s+x_e)//2
    x_s = x_c-newsize[1]//2
    x_e = x_c+newsize[1]//2
    img = img[y_s:y_e,x_s if x_s>0 else 0:x_e if x_e<img.shape[1] else img.shape[1]]
    return cv2.resize(img,newsize)


# In[5]:


images = [image_extract(i,(64,64)) for i in images]


# In[6]:


plt.figure()
for i in range(15):
    plt.subplot(3,5,i+1)
    plt.imshow(images[i])
plt.show()


# In[7]:


gei = np.mean(images,axis=0)


# In[8]:


plt.imshow(gei)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [120], in <cell line: 60>()
#      54     return cv2.resize(img,newsize)
#      57 # In[5]:
# ---> 60 images = [image_extract(i,(64,64)) for i in images]
#      63 # In[6]:
#      66 plt.figure()
#
# Input In [120], in <listcomp>(.0)
#      54     return cv2.resize(img,newsize)
#      57 # In[5]:
# ---> 60 images = [image_extract(i,(64,64)) for i in images]
#      63 # In[6]:
#      66 plt.figure()
#
# Input In [120], in image_extract(img, newsize)
#      42 def image_extract(img,newsize):
# ---> 43     x_s = np.where(img.mean(axis=0)!=0)[0].min()
#      44     x_e = np.where(img.mean(axis=0)!=0)[0].max()
#      46     y_s = np.where(img.mean(axis=1)!=0)[0].min()
#
# File ~\anaconda3\envs\gait\lib\site-packages\numpy\core\_methods.py:44, in _amin(a, axis, out, keepdims, initial, where)
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
# ---> 44     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
def get_ppl_block(images, resize):
    def mass_center(img,is_round=True):
        Y = img.mean(axis=1)
        X = img.mean(axis=0)
        Y_ = np.sum(np.arange(Y.shape[0]) * Y)/np.sum(Y)
        X_ = np.sum(np.arange(X.shape[0]) * X)/np.sum(X)
        if is_round:
            return int(round(X_)),int(round(Y_))
        return X_,Y_

    def image_extract(img,newsize):
        x_s = np.where(img.mean(axis=0)!=0)[0].min()
        x_e = np.where(img.mean(axis=0)!=0)[0].max()

        y_s = np.where(img.mean(axis=1)!=0)[0].min()
        y_e = np.where(img.mean(axis=1)!=0)[0].max()

        x_c,_ = mass_center(img)
    #     x_c = (x_s+x_e)//2
        x_s = x_c-newsize[1]//2
        x_e = x_c+newsize[1]//2
        img = img[y_s:y_e,x_s if x_s>0 else 0:x_e if x_e<img.shape[1] else img.shape[1]]
        return cv2.resize(img,newsize)

    crop_images = [image_extract(i, resize) for i in images]
    return crop_images

# %%
def Period_Detection(gallery: np.array, gallery_shape: tuple, alpha = 0.470, beta = 0.961) -> np.array:
    '''
    hip, knee, and ankle are 0.470, 0.715, 0.961
    '''
    
    #設定move_region的y軸最上和最下
    #這裡設為hip到ankle
    start = round(gallery_shape[0] * alpha)
    end = round(gallery_shape[0] * beta)
    
    period_result = np.empty(gallery.shape[0])
    
    for i, img in enumerate(gallery):
        move_region_aggregate = 0
        
        for h in range(start, end):
            
            #找出人在剪影中的最左和最右
            nonzero_index = list(np.nonzero(img[h])[0])
    
            if not nonzero_index:
                # 如果都是背景(全黑)則跳過
                continue
            left_most, right_most = nonzero_index[0], nonzero_index[-1]
            
            #算出最左和最右的pixel距離，也就是算出人體在剪影的擺動幅度
            move_region_aggregate  = move_region_aggregate + (right_most - left_most)
            
        #平均
        move_region_aggregate /= float((end - start + 1))
        period_result[i] = move_region_aggregate
        
    if period_result.shape[0] == 1:
        return period_result
    
    #normalize
    period_result = (period_result - np.min(period_result)) / np.ptp(period_result)
    
 
    
    return period_result

# %%
files = os.listdir(r'C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\079\bg-01\054')
images = [cv2.imread(r'C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\079\bg-01\054'+'\\'+f, -1) for f in files]
images = get_ppl_block(images, (64, 64))
images = np.array(images)

# %%
plt.figure()
for i in range(15):
    plt.subplot(3,5,i+1)
    plt.imshow(images[i])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [91], in <cell line: 2>()
#       2 for i in range(15):
#       3     plt.subplot(3,5,i+1)
# ----> 4     plt.imshow(images[i])
#       5 plt.show()
#
# IndexError: index 8 is out of bounds for axis 0 with size 8

# %%
period = Period_Detection(gallery=images, gallery_shape=images[0].shape)

# %%
period
# Out:
# array([0.        , 0.55555556, 0.86419753, 0.9382716 , 0.95061728,
#        1.        , 0.92592593, 0.69135802])

# %%
plt.plot([i for i, _ in enumerate(period)], period, '-o')

# %%
def Tk(m=0.3, nc=5) -> list:
    result = []
    for k in range(1, nc+1):
        tmp = [k/(nc+1) - (m/2), k/(nc+1) + m/2]
        result.append(tmp)
    return result

# %%
Tk()
# Out:
# [[0.016666666666666663, 0.31666666666666665],
#  [0.18333333333333332, 0.4833333333333333],
#  [0.35, 0.65],
#  [0.5166666666666666, 0.8166666666666667],
#  [0.6833333333333333, 0.9833333333333334]]

# %%
tk2_image = images[np.where((period > Tk()[1][0]) & (period < Tk()[1][1]))]

# %%
tk2_image.shape[0]
# Out:
# 0

# %%
def GEI(images: np.array, resize: tuple, draw: bool = False) -> list:

    def mass_center(img,is_round=True):
        Y = img.mean(axis=1)
        X = img.mean(axis=0)
        Y_ = np.sum(np.arange(Y.shape[0]) * Y)/np.sum(Y)
        X_ = np.sum(np.arange(X.shape[0]) * X)/np.sum(X)
        if is_round:
            return int(round(X_)),int(round(Y_))
        return X_,Y_

    def image_extract(img,newsize):
        x_s = np.where(img.mean(axis=0)!=0)[0].min()
        x_e = np.where(img.mean(axis=0)!=0)[0].max()

        y_s = np.where(img.mean(axis=1)!=0)[0].min()
        y_e = np.where(img.mean(axis=1)!=0)[0].max()

        x_c,_ = mass_center(img)
    #     x_c = (x_s+x_e)//2
        x_s = x_c-newsize[1]//2
        x_e = x_c+newsize[1]//2
        img = img[y_s:y_e,x_s if x_s>0 else 0:x_e if x_e<img.shape[1] else img.shape[1]]
        return cv2.resize(img,newsize)

    images = [image_extract(i, resize) for i in images]
    gei = np.mean(images,axis=0)
    if draw:
        plt.imshow(gei)
        plt.show()
    
    return gei

# %%
for i in Tk():
    tk_image = images[np.where((period > i[0]) & (period < i[1]))]
    GEI(tk_image, (64, 64), draw=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
#       1 for i in Tk():
# ----> 2     tk_image = images[np.where((period > i[0]) & (period < i[1]))]
#       3     GEI(tk_image, (64, 64), draw=True)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
g = os.walk(r'C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh', topdown=False)

# %%
root = r'C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh'
subjects = os.listdir(root)
variations = os.listdir(root +'\\'+ subjects[0])
angles = os.listdir(root +'\\'+ subjects[0] + '\\' + variations[0])

ourputdir = r'C:\Users\User\Desktop\Aaron\College-level Applied Research\PEI_output'

if not os.path.isdir(ourputdir):
    os.mkdir(ourputdir)

for sub in subjects:
    sub_dir = f'{ourputdir}\\{sub}'
    if not os.path.isdir(sub_dir):
        os.mkdir(sub_dir)
        
    for var in variations:
        var_dir = f'{sub_dir}\\{var}'
        if not os.path.isdir(var_dir):
            os.mkdir(var_dir)
            
        for ang in angles:
            ang_dir = f'{var_dir}\\{ang}'
            if not os.path.isdir(ang_dir):
                os.mkdir(ang_dir)
            
            images_dir = f'{root}\\{sub}\\{var}\\{ang}'
            images_filename = os.listdir(images_dir)
            images = [cv2.imread(images_dir+'\\'+ f, -1) for f in images_filename]
            
            if images:           
                images_crop = images.copy()
                images_crop = get_ppl_block(images_crop, (64, 64))
                images_crop = np.array(images_crop)
                period = Period_Detection(gallery=images_crop, gallery_shape=images_crop[0].shape)
                for i, minmax in enumerate(Tk()):
                    images = np.array(images)
                    tk_image = images[np.where((period > minmax[0]) & (period < minmax[1]))]
                    if tk_image.shape[0] > 1:
                        gei = GEI(tk_image, (64, 64))
#                         plt.imshow(gei)
#                         plt.show()
                        cv2.imwrite(f'{ang_dir}\gei_{i}.png', gei)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [119], in <cell line: 11>()
#      30 if images:
#      31     images_crop = images.copy()
# ---> 32     images_crop = get_ppl_block(images_crop, (64, 64))
#      33     images_crop = np.array(images_crop)
#      34     period = Period_Detection(gallery=images_crop, gallery_shape=images_crop[0].shape)
#
# Input In [22], in get_ppl_block(images, resize)
#      22     img = img[y_s:y_e,x_s if x_s>0 else 0:x_e if x_e<img.shape[1] else img.shape[1]]
#      23     return cv2.resize(img,newsize)
# ---> 25 crop_images = [image_extract(i, resize) for i in images]
#      26 return crop_images
#
# Input In [22], in <listcomp>(.0)
#      22     img = img[y_s:y_e,x_s if x_s>0 else 0:x_e if x_e<img.shape[1] else img.shape[1]]
#      23     return cv2.resize(img,newsize)
# ---> 25 crop_images = [image_extract(i, resize) for i in images]
#      26 return crop_images
#
# Input In [22], in get_ppl_block.<locals>.image_extract(img, newsize)
#      11 def image_extract(img,newsize):
# ---> 12     x_s = np.where(img.mean(axis=0)!=0)[0].min()
#      13     x_e = np.where(img.mean(axis=0)!=0)[0].max()
#      15     y_s = np.where(img.mean(axis=1)!=0)[0].min()
#
# File ~\anaconda3\envs\gait\lib\site-packages\numpy\core\_methods.py:44, in _amin(a, axis, out, keepdims, initial, where)
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
# ---> 44     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
import shutil

root = r'C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh'
subjects = os.listdir(root)
variations = os.listdir(root +'\\'+ subjects[0])
angles = os.listdir(root +'\\'+ subjects[0] + '\\' + variations[0])

ourputdir = r'C:\Users\User\Desktop\Aaron\College-level Applied Research\PEI_output'

if not os.path.isdir(ourputdir):
    os.mkdir(ourputdir)

for sub in subjects:
    sub_dir = f'{ourputdir}\\{sub}'
    if not os.path.isdir(sub_dir):
        os.mkdir(sub_dir)
        
    for var in variations:
        var_dir = f'{sub_dir}\\{var}'
        if not os.path.isdir(var_dir):
            os.mkdir(var_dir)
            
        for ang in angles:
            ang_dir = f'{var_dir}\\{ang}'
            if not os.path.isdir(ang_dir):
                os.mkdir(ang_dir)
            
            images_dir = f'{root}\\{sub}\\{var}\\{ang}'
            images_filename = os.listdir(images_dir)
            if not images_filename:
                print(images_dir)
                shutil.rmtree(images_dir)
                
            else:
                for f in images_filename:
                    img_file_dir = images_dir+'\\'+ f
                    img = cv2.imread(img_file_dir)
                    if (img == np.zeros(img.shape)).all():
                        print(img_file_dir)
                        os.remove(img_file_dir)
                    
#             images = [cv2.imread(images_dir+'\\'+ f, -1) for f in images_filename]
# Out:
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-001.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-002.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-003.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-004.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-005.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-006.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-007.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-008.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-009.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-010.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-011.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-012.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-013.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-014.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-015.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-016.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-017.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-018.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-019.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-020.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-021.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-022.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-023.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-024.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-025.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-026.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-027.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-028.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-029.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-030.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-031.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-032.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-033.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-034.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-035.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-036.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-037.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-038.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-039.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-040.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-041.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-042.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-043.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-044.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-045.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-046.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-047.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-048.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-049.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-050.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-051.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-052.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-053.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-054.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-055.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-056.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-057.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-058.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-059.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-060.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-061.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-062.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-063.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-064.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-065.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-066.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-067.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-068.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-069.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-070.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-071.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-072.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-073.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-074.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-075.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-076.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-077.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-078.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-079.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-080.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-081.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-082.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-083.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-084.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-085.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-086.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-087.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-088.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\000\001-bg-01-000-089.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-001.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-002.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-003.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-004.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-005.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-006.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-007.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-008.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-009.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-010.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-011.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-012.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-013.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-014.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-015.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-016.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-017.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-018.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-019.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-020.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-021.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-022.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-023.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-024.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-025.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-026.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-027.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-028.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-029.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-030.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-031.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-032.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-033.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-034.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-035.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-036.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-037.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-038.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-039.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-040.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-041.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-042.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-043.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-044.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-045.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-046.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-047.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-048.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-049.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-050.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-051.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-052.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-053.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-054.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-055.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-056.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-057.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-058.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-059.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-060.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-061.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-062.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-063.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-064.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-065.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-066.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-067.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-068.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-069.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-070.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-071.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-072.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-073.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-074.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-075.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-076.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-077.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-078.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-079.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-080.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-081.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-082.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-083.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-084.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-085.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-086.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-087.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-088.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-089.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-090.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\018\001-bg-01-018-091.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-001.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-002.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-003.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-004.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-005.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-006.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-007.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-008.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-009.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-010.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-011.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-012.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-013.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-014.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-015.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-016.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-017.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-018.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-019.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-020.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-021.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-022.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-023.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-024.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-025.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-026.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-027.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-028.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-029.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-030.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-031.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-032.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-033.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-034.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-035.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-036.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-037.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-038.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-039.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-040.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-041.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-042.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-043.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-044.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-045.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-046.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-047.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-048.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-049.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-050.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-051.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-052.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-053.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-054.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-055.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-056.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-057.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-058.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-059.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-060.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-061.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-062.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-063.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-064.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-065.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-066.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-067.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-068.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-069.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-070.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-071.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-072.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-073.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-074.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-075.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-076.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-077.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-078.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-079.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-080.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-081.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-082.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-083.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-084.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-085.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-086.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\036\001-bg-01-036-087.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-007.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-008.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-009.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-010.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-011.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-012.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-013.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-014.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-015.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-016.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-017.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-018.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-019.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-020.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-021.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-022.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-023.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-024.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-025.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-026.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-027.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-028.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-029.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-030.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-031.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-032.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-033.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-034.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-035.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-036.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-037.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-038.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-039.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-040.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-041.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-042.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-043.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-044.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-045.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-046.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-047.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-048.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-049.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-050.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-051.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-052.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-053.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-054.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-055.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-056.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-057.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-058.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-059.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-060.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-061.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-062.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-063.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-064.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-065.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-066.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-067.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-068.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-069.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-070.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-071.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-072.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-073.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-074.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-075.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-076.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-077.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-078.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-079.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-080.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-081.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-082.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-083.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-084.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-085.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-086.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-087.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-088.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-089.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-090.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-091.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-092.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\054\001-bg-01-054-093.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-031.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-032.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-033.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-034.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-035.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-036.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-037.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-038.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-039.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-040.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-041.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-042.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-043.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-044.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-045.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-046.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-047.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-048.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-049.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-050.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-051.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-052.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-053.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-054.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-055.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-056.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-057.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-058.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-059.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-060.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-061.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-062.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-063.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-064.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-065.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-066.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-067.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-068.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-069.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-070.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-071.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\bg-01\072\001-bg-01-072-072.png
# ...
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\000\001-cl-02-000-072.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\000\001-cl-02-000-073.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\000\001-cl-02-000-074.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\000\001-cl-02-000-075.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\000\001-cl-02-000-076.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\000\001-cl-02-000-077.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\000\001-cl-02-000-078.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\000\001-cl-02-000-079.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\000\001-cl-02-000-080.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\000\001-cl-02-000-081.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\000\001-cl-02-000-082.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\000\001-cl-02-000-083.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\000\001-cl-02-000-084.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-001.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-002.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-003.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-004.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-005.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-006.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-007.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-008.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-009.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-010.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-011.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-012.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-013.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-014.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-015.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-016.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-017.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-018.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-019.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-020.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-021.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-022.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-023.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-024.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-025.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-026.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-027.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-028.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-029.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-030.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-031.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-032.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-033.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-034.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-035.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-036.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-037.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-038.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-039.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-040.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-041.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-042.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-043.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-044.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-045.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-046.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-047.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-048.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-049.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-050.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-051.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-052.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-053.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-054.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-055.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-056.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-057.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-058.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-059.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-060.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-061.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-062.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-063.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-064.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-065.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-066.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-067.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-068.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-069.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-070.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-071.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-072.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-073.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-074.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-075.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-076.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-077.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-078.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-079.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-080.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-081.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-082.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-083.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-084.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-085.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-086.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-087.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-088.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-089.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-090.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-091.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-092.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\018\001-cl-02-018-093.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\036\001-cl-02-036-001.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\036\001-cl-02-036-002.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\036\001-cl-02-036-003.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\036\001-cl-02-036-004.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\036\001-cl-02-036-005.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\036\001-cl-02-036-006.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\036\001-cl-02-036-007.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\036\001-cl-02-036-008.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\036\001-cl-02-036-009.png
# C:\Users\User\Desktop\Aaron\College-level Applied Research\CASIA-B\GaitDatasetB-silh\001\cl-02\036\001-cl-02-036-010.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [124], in <cell line: 13>()
#      37 img = cv2.imread(img_file_dir)
#      38 if (img == np.zeros(img.shape)).all:
# ---> 39     print(img_file_dir)
#      40     os.remove(img_file_dir)
#
# File ~\anaconda3\envs\gait\lib\site-packages\ipykernel\iostream.py:531, in OutStream.write(self, string)
#     529 is_child = (not self._is_master_process())
#     530 # only touch the buffer in the IO thread to avoid races
# --> 531 self.pub_thread.schedule(lambda: self._buffer.write(string))
#     532 if is_child:
#     533     # mp.Pool cannot be trusted to flush promptly (or ever),
#     534     # and this helps.
#     535     if self._subprocess_flush_pending:
#
# File ~\anaconda3\envs\gait\lib\site-packages\ipykernel\iostream.py:216, in IOPubThread.schedule(self, f)
#     214     self._events.append(f)
#     215     # wake event thread (message content is ignored)
# --> 216     self._event_pipe.send(b'')
#     217 else:
#     218     f()
#
# File ~\anaconda3\envs\gait\lib\site-packages\zmq\sugar\socket.py:547, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     540         data = zmq.Frame(
#     541             data,
#     542             track=track,
#     543             copy=copy or None,
#     544             copy_threshold=self.copy_threshold,
#     545         )
#     546     data.group = group
# --> 547 return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#
# File zmq\backend\cython\socket.pyx:718, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:765, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:242, in zmq.backend.cython.socket._send_copy()
#
# File ~\anaconda3\envs\gait\lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
np.zeros((2,2))
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
(img == np.zeros(img.shape)).all()
# Out:
# False
